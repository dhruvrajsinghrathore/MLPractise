# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd

# %%
#Now we'll learn how to deal with missing data, a very common task when analyzing datasets!

data = pd.Series(['one','two', np.nan, 'four'])

# %%
data
# Out:
# 0     one
# 1     two
# 2     NaN
# 3    four
# dtype: object

# %%
data.all()
# Out:
# 'four'

# %%
data.any()
# Out:
# 'one'

# %%
data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data.dropna()
# Out:
# 0     one
# 1     two
# 3    four
# dtype: object

# %%
del data[0]

# %%
data
# Out:
# 1     two
# 2     NaN
# 3    four
# dtype: object

# %%
# In a DataFrame we need to be a little more careful!

dframe = DataFrame([[1,2,3],[np.nan,5,6],[7,np.nan,9],[np.nan,np.nan,np.nan]])

# %% [markdown]
# dframe

# %%
dframe
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0
# 3  NaN  NaN  NaN

# %%
dframe.dropna(how="all")
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0

# %%
#We can also threshold teh missing data as well

#For example if we only want rows with at least 3 data points
dframe2 = DataFrame([[1,2,3,np.nan],[2,np.nan,5,6],[np.nan,7,np.nan,9],[1,np.nan,np.nan,np.nan]])

#Show
dframe2
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0
# 2  NaN  7.0  NaN  9.0
# 3  1.0  NaN  NaN  NaN

# %%
dframe2.dropna(thresh=3)
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0

# %%
#If we want to modify the exsisting object, use inplace
dframe2.fillna({0:1,1:2,2:3,3:4})
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  0.0
# 1  2.0  0.0  5.0  6.0
# 2  0.0  7.0  0.0  9.0
# 3  1.0  0.0  0.0  0.0

# %%
dframe2
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  0.0
# 1  2.0  0.0  5.0  6.0
# 2  0.0  7.0  0.0  9.0
# 3  1.0  0.0  0.0  0.0

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\dhruv\Desktop\google.csv')

# %%
df[['Open','High','Low']]
# Out:
#             Open        High         Low
# 0     585.002622  587.342658  584.002627
# 1     576.112580  584.512631  576.002598
# 2     577.862619  579.382595  570.522603
# 3     576.182596  577.902645  570.882599
# 4     567.312567  575.002602  565.752564
# ...          ...         ...         ...
# 2513  104.960181  108.000187  103.880180
# 2514  111.240189  111.600192  103.570177
# 2515  110.750191  113.480193  109.050183
# 2516  101.010175  109.080187  100.500174
# 2517  100.000168  104.060182   95.960165
#
# [2518 rows x 3 columns]

# %%
print(df.iterrows())
# Out:
# <generator object DataFrame.iterrows at 0x0000021905C5AC10>

# %%
import pandas as pd
from pandas import Series,DataFrame
xlxfile  = pd.read_excel(r'C:\Users\dhruv\Downloads\Excel102Exercises (1).xlsx')
xlxfile
# Out:
#   Circulation Results 2013   Unnamed: 1
# 0                      NaN          NaN
# 1                     Town  Circulation
# 2                  Beverly       985134
# 3               Cherrydale      1369696
# 4                Jamestown      1966973
# 5                Larksburg      1145699
# 6              Washerville       968645

# %%
dframee = DataFrame(data=xlxfile,columns = xlxfile.columns)
dframee
# Out:
#   Circulation Results 2013   Unnamed: 1
# 0                      NaN          NaN
# 1                     Town  Circulation
# 2                  Beverly       985134
# 3               Cherrydale      1369696
# 4                Jamestown      1966973
# 5                Larksburg      1145699
# 6              Washerville       968645

# %%
xls = pd.ExcelFile(r'C:\Users\dhruv\Downloads\Excel102Exercises (1).xlsx')
df1 = pd.read_excel(xls, 'Subtotals')

# %%
df1
# Out:
#    Salesperson                   Product  Units  Price/Unit     Sales
# 0     Cattapan  Chocolate Chocolate Chip   99.0       10.00    990.00
# 1     Cattapan             Fudge Brownie   61.0       13.00    793.00
# 2     Cattapan                Strawberry   28.0       13.50    378.00
# 3     Cattapan                   Vanilla   75.0       11.20    840.00
# 4     Cattapan                   Vanilla   80.0       11.20    896.00
# 5     Cattapan                   Vanilla   80.0       11.20    896.00
# 6     DeMarcos  Chocolate Chocolate Chip   75.0       11.00    825.00
# 7     DeMarcos             Fudge Brownie   75.0       12.65    948.75
# 8     DeMarcos             Fudge Brownie   68.0       12.65    860.20
# 9     DeMarcos                Strawberry   86.0       10.00    860.00
# 10    DeMarcos                   Vanilla   55.0       12.55    690.25
# 11    DeMarcos                   Vanilla   65.0       12.55    815.75
# ...

# %%
for index,row in df1.iterrows():
    print(index,row[1])
# Out:
# 0 Chocolate Chocolate Chip
# 1 Fudge Brownie
# 2 Strawberry
# 3 Vanilla
# 4 Vanilla
# 5 Vanilla
# 6 Chocolate Chocolate Chip
# 7 Fudge Brownie
# 8 Fudge Brownie
# 9 Strawberry
# 10 Vanilla
# 11 Vanilla
# 12 Chocolate Chocolate Chip
# 13 Fudge Brownie
# 14 Strawberry
# 15 Strawberry
# 16 Vanilla
# 17 Chocolate Chocolate Chip
# 18 Fudge Brownie
# 19 Strawberry
# 20 Strawberry
# 21 Strawberry
# 22 Vanilla
# 23 Chocolate Chocolate Chip
# 24 Fudge Brownie
# 25 Fudge Brownie
# 26 Strawberry
# 27 Vanilla
# 28 Vanilla
# 29 Chocolate Chocolate Chip
# 30 Fudge Brownie
# 31 Strawberry
# 32 Vanilla
# 33 Vanilla
# 34 Vanilla
# 35 Vanilla
# 36 Chocolate Chocolate Chip
# 37 Fudge Brownie
# 38 Strawberry
# 39 Vanilla
# 40 Vanilla
# 41 Vanilla
# 42 nan

# %%
df1.loc[df1["Product"] == "Vanilla"]
# Out:
#    Salesperson  Product  Units  Price/Unit    Sales
# 3     Cattapan  Vanilla   75.0       11.20   840.00
# 4     Cattapan  Vanilla   80.0       11.20   896.00
# 5     Cattapan  Vanilla   80.0       11.20   896.00
# 10    DeMarcos  Vanilla   55.0       12.55   690.25
# 11    DeMarcos  Vanilla   65.0       12.55   815.75
# 16      Packet  Vanilla   95.0       10.55  1002.25
# 22   Patterson  Vanilla   62.0       11.00   682.00
# 27     Sergeto  Vanilla   80.0       11.00   880.00
# 28     Sergeto  Vanilla   95.0       11.00  1045.00
# 32       Smith  Vanilla   60.0       12.55   753.00
# 33       Smith  Vanilla   65.0       12.55   815.75
# 34       Smith  Vanilla   56.0       12.55   702.80
# 35       Smith  Vanilla   68.0       12.55   853.40
# 39      Wilson  Vanilla  110.0        9.99  1098.90
# 40      Wilson  Vanilla   65.0        9.99   649.35
# 41      Wilson  Vanilla   90.0        9.99   899.10

# %%
df_sort = df1.sort_values("Salesperson",ascending= False)
df_sort = df_sort.reset_index(drop=True)
df_sort
# Out:
#    Salesperson                   Product  Units  Price/Unit     Sales
# 0       Wilson                   Vanilla   90.0        9.99    899.10
# 1       Wilson                   Vanilla   65.0        9.99    649.35
# 2       Wilson                   Vanilla  110.0        9.99   1098.90
# 3       Wilson                Strawberry   81.0       10.00    810.00
# 4       Wilson             Fudge Brownie  100.0        9.99    999.00
# 5       Wilson  Chocolate Chocolate Chip   73.0       11.60    846.80
# 6        Smith                Strawberry   52.0       13.60    707.20
# 7        Smith  Chocolate Chocolate Chip   70.0       11.00    770.00
# 8        Smith             Fudge Brownie   23.0       16.00    368.00
# 9        Smith                   Vanilla   60.0       12.55    753.00
# 10       Smith                   Vanilla   65.0       12.55    815.75
# 11       Smith                   Vanilla   56.0       12.55    702.80
# ...

# %%
df1['Total'] = df1["Units"]*df1["Sales"]

# %%
df1.drop(columns = ["Total","Sales"])
# Out:
#    Salesperson                   Product  Units  Price/Unit
# 0     Cattapan  Chocolate Chocolate Chip   99.0       10.00
# 1     Cattapan             Fudge Brownie   61.0       13.00
# 2     Cattapan                Strawberry   28.0       13.50
# 3     Cattapan                   Vanilla   75.0       11.20
# 4     Cattapan                   Vanilla   80.0       11.20
# 5     Cattapan                   Vanilla   80.0       11.20
# 6     DeMarcos  Chocolate Chocolate Chip   75.0       11.00
# 7     DeMarcos             Fudge Brownie   75.0       12.65
# 8     DeMarcos             Fudge Brownie   68.0       12.65
# 9     DeMarcos                Strawberry   86.0       10.00
# 10    DeMarcos                   Vanilla   55.0       12.55
# 11    DeMarcos                   Vanilla   65.0       12.55
# 12      Packet  Chocolate Chocolate Chip   95.0       10.55
# 13      Packet             Fudge Brownie   95.0       10.55
# 14      Packet                Strawberry   90.0       10.90
# ...

# %%
df1.to_csv("Second_Salesperson_Info.csv",index=False)

# %%
df1.to_excel("secondd_salesperson_info.xlsx",index=False)

# %%
df1.loc[df1["Product"].str.contains("Vanilla|Strawberry",na=False)].reset_index(drop=True)
# Out:
#    Salesperson     Product  Units  Price/Unit    Sales      Total
# 0     Cattapan  Strawberry   28.0       13.50   378.00   10584.00
# 1     Cattapan     Vanilla   75.0       11.20   840.00   63000.00
# 2     Cattapan     Vanilla   80.0       11.20   896.00   71680.00
# 3     Cattapan     Vanilla   80.0       11.20   896.00   71680.00
# 4     DeMarcos  Strawberry   86.0       10.00   860.00   73960.00
# 5     DeMarcos     Vanilla   55.0       12.55   690.25   37963.75
# 6     DeMarcos     Vanilla   65.0       12.55   815.75   53023.75
# 7       Packet  Strawberry   90.0       10.90   981.00   88290.00
# 8       Packet  Strawberry  110.0       10.90  1199.00  131890.00
# 9       Packet     Vanilla   95.0       10.55  1002.25   95213.75
# 10   Patterson  Strawberry   92.0       11.50  1058.00   97336.00
# 11   Patterson  Strawberry   95.0       10.55  1002.25   95213.75
# 12   Patterson  Strawberry   90.0       10.55   949.50   85455.00
# ...

# %%
#changing fields name
df1.loc[df1["Product"]=="Vanilla","Product"]="Mango"
df1
# Out:
#    Salesperson                   Product  Units  Price/Unit     Sales  \
# 0     Cattapan  Chocolate Chocolate Chip   99.0       10.00    990.00
# 1     Cattapan             Fudge Brownie   61.0       13.00    793.00
# 2     Cattapan                Strawberry   28.0       13.50    378.00
# 3     Cattapan                     Mango   75.0       11.20    840.00
# 4     Cattapan                     Mango   80.0       11.20    896.00
# 5     Cattapan                     Mango   80.0       11.20    896.00
# 6     DeMarcos  Chocolate Chocolate Chip   75.0       11.00    825.00
# 7     DeMarcos             Fudge Brownie   75.0       12.65    948.75
# 8     DeMarcos             Fudge Brownie   68.0       12.65    860.20
# 9     DeMarcos                Strawberry   86.0       10.00    860.00
# 10    DeMarcos                     Mango   55.0       12.55    690.25
# 11    DeMarcos                     Mango   65.0       12.55    815.75
# ...

# %%
df1.groupby(["Product"]).mean().sort_values("Price/Unit",ascending=False)
# Out:
#                               Units  Price/Unit       Sales         Total
# Product
# Fudge Brownie             75.777778   11.982222  870.133333  70083.400000
# Mango                     75.062500   11.401250  844.971875  65257.359375
# Strawberry                80.900000   11.300000  892.245000  76820.065000
# Chocolate Chocolate Chip  74.428571   11.242857  824.771429  63434.014286

# %%
df.groupby(["Salesperson","Product"]).count()['Total']
# Out:
# Salesperson  Product
# Cattapan     Chocolate Chocolate Chip    1
#              Fudge Brownie               1
#              Strawberry                  1
#              Vanilla                     3
# DeMarcos     Chocolate Chocolate Chip    1
#              Fudge Brownie               2
#              Strawberry                  1
#              Vanilla                     2
# Packet       Chocolate Chocolate Chip    1
#              Fudge Brownie               1
#              Strawberry                  2
#              Vanilla                     1
# Patterson    Chocolate Chocolate Chip    1
#              Fudge Brownie               1
#              Strawberry                  3
#              Vanilla                     1
# Sergeto      Chocolate Chocolate Chip    1
#              Fudge Brownie               2
#              Strawberry                  1
#              Vanilla                     2
# Smith        Chocolate Chocolate Chip    1
# ...
